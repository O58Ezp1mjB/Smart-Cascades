# %%
import pandas as pd
import numpy as np
import gc
import os
from pytorch_tabnet.tab_model import TabNetRegressor
import torch

# 'TSP' is our paper project code
from pytorch_tabnet.TSP_implement import TSP_Loss

import json

# %% [markdown]
# ## Hyperparameters and Settings
# - `data_path_fast` and `data_path_expensive` are datasets for an estimator that can be replaced. Please select the dataset for a specific fast/expensive model in `./dataset_estimator/ImageNet`.
#
# - `lambda_CDC_weight` is the `lambda` in the paper.
#
# - The trained weight will be stored in `./estimator_weights/weights_ImageNet_{fast_model}_{expensive_model}`

# %%
root = os.path.abspath('.')

# dataset path
data_path_fast= os.path.join(root,'dataset_estimator','ImageNet','tf_efficientnet_b0_ImageNet_dataset.csv')
data_path_expensive=os.path.join(root,'dataset_estimator','ImageNet','resnet101_ImageNet_dataset.csv')

# setting
dataset_split_type = 'split_by_json' # 'split_by_json' or 'split_by_random'
json_for_estimator = os.path.join(root,'seeds_json','ImageNet_json_split_for_estimator_1.json')

# The metric is used for early stopping
eval_metric=['AIR'] # 'AIR' or 'TSP-Loss-Overall'

learning_rate = 1e-2
max_epochs = 200

lambda_CDC_weight = 0.2 # 0.1, 0.15 or 0.2
Loss_Base_weight = 1.0

# %% [markdown]
# ## Processing settings

# %%
# save weight name
if lambda_CDC_weight != 0:
    loss_type = "L-Overall"
else: 
    loss_type = "L-Base"

if eval_metric[-1] == 'TSP-Loss-Overall':
    metric_name = "Loss"
else: 
    metric_name = "AIR"

seed_id = json_for_estimator.split('_')[-1].split('.')[0]

shallow_name = os.path.split(data_path_fast.split('_dataset')[0])[-1]
deep_name = os.path.split(data_path_expensive.split('_dataset')[0])[-1]

saving_weight_name = os.path.join(root,'estimator_weights',f'weights_ImageNet_{shallow_name}_{deep_name}',f'TabNet_{loss_type}_{metric_name}_Seed_{seed_id}')

# %% [markdown]
# ## Processing the data

# %%
data_shallow = pd.read_csv(data_path_fast,header=0)
print(data_shallow.shape)

data_shallow.head()
# Out:
# (64056, 1003)
#    index_in_dataset  correctness  correct_cls_index  prob_index_0  \
# 0           1022729            1                798  3.016706e-07
# 1            616088            1                479  3.725413e-05
# 2            376291            1                294  1.502893e-04
# 3            819303            0                638  3.032851e-06
# 4            523820            1                408  2.350180e-05
#
#    prob_index_1  prob_index_2  prob_index_3  prob_index_4  prob_index_5  \
# 0      0.000001      0.000005      0.000004      0.000004  2.358331e-05
# 1      0.000041      0.000060      0.000187      0.000156  1.999536e-04
# 2      0.000139      0.000136      0.000035      0.000239  2.784144e-04
# 3      0.000003      0.000003      0.000002      0.000002  4.118787e-07
# 4      0.000028      0.000065      0.000051      0.000024  4.494722e-05
#
#    prob_index_6  ...  prob_index_990  prob_index_991  prob_index_992  \
# 0      0.000003  ...        0.000002        0.000002        0.000002
# 1      0.000133  ...        0.000059        0.000073        0.000135
# 2      0.000143  ...        0.000048        0.000137        0.000104
# 3      0.000003  ...        0.000007        0.000009        0.000007
# 4      0.000103  ...        0.000009        0.000057        0.000049
#
#    prob_index_993  prob_index_994  prob_index_995  prob_index_996  \
# 0        0.000002        0.000001        0.000008        0.000001
# 1        0.000115        0.000138        0.000380        0.000099
# 2        0.000048        0.000084        0.000052        0.000061
# 3        0.000005        0.000015        0.000023        0.000004
# 4        0.000062        0.000028        0.000003        0.000015
#
#    prob_index_997  prob_index_998  prob_index_999
# 0        0.000002        0.000026        0.000005
# 1        0.000118        0.000109        0.000098
# 2        0.000063        0.000075        0.000175
# 3        0.000055        0.000003        0.000008
# 4        0.000068        0.000054        0.000160
#
# [5 rows x 1003 columns]

# %%
data_deep = pd.read_csv(data_path_expensive,header=0)
print(data_deep.shape)

data_deep.head()
# Out:
# (64056, 1003)
#    index_in_dataset  correctness  correct_cls_index  prob_index_0  \
# 0           1022729            1                798      0.000001
# 1            616088            1                479      0.000097
# 2            376291            1                294      0.000338
# 3            819303            0                638      0.000159
# 4            523820            1                408      0.000132
#
#    prob_index_1  prob_index_2  prob_index_3  prob_index_4  prob_index_5  \
# 0  8.676604e-07      0.000002  7.610744e-07      0.000002      0.000002
# 1  1.246419e-04      0.000098  1.952513e-04      0.000052      0.000102
# 2  6.952937e-05      0.000046  1.501845e-04      0.000151      0.000084
# 3  1.215740e-04      0.000170  3.645422e-05      0.000408      0.000255
# 4  8.513094e-05      0.000248  7.586108e-05      0.000183      0.000123
#
#    prob_index_6  ...  prob_index_990  prob_index_991  prob_index_992  \
# 0  4.783777e-07  ...    8.534692e-07        0.000003        0.000002
# 1  1.192066e-04  ...    1.321169e-04        0.000082        0.000205
# 2  7.681140e-05  ...    5.494538e-05        0.000093        0.000078
# 3  1.105206e-04  ...    2.582925e-04        0.000253        0.000216
# 4  1.160375e-04  ...    9.529041e-05        0.000141        0.000170
#
#    prob_index_993  prob_index_994  prob_index_995  prob_index_996  \
# 0        0.000002        0.000001    7.887821e-07    7.520305e-07
# 1        0.000204        0.000215    4.614002e-05    4.976594e-05
# 2        0.000153        0.000150    1.367076e-04    9.844397e-05
# 3        0.000172        0.000213    2.282218e-04    7.214426e-05
# 4        0.000110        0.000173    1.211055e-04    5.923554e-05
#
#    prob_index_997  prob_index_998  prob_index_999
# 0        0.000003        0.000001    8.415565e-07
# 1        0.000065        0.000061    2.028638e-05
# 2        0.000128        0.000034    2.950774e-04
# 3        0.000430        0.000189    1.136141e-04
# 4        0.000130        0.000092    1.753411e-04
#
# [5 rows x 1003 columns]

# %%
# check filename
print(data_shallow.iloc[:,0]==data_deep.iloc[:,0])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 64051    True
# 64052    True
# 64053    True
# 64054    True
# 64055    True
# Name: index_in_dataset, Length: 64056, dtype: bool

# %%
traning_data=pd.concat([data_shallow.iloc[:,3:],data_deep.iloc[:,3:],data_shallow.iloc[:,1],data_deep.iloc[:,1],data_shallow.iloc[:,2]],axis=1)
print(traning_data.shape)
traning_data.head()
# Out:
# (64056, 2003)
#    prob_index_0  prob_index_1  prob_index_2  prob_index_3  prob_index_4  \
# 0  3.016706e-07      0.000001      0.000005      0.000004      0.000004
# 1  3.725413e-05      0.000041      0.000060      0.000187      0.000156
# 2  1.502893e-04      0.000139      0.000136      0.000035      0.000239
# 3  3.032851e-06      0.000003      0.000003      0.000002      0.000002
# 4  2.350180e-05      0.000028      0.000065      0.000051      0.000024
#
#    prob_index_5  prob_index_6  prob_index_7  prob_index_8  prob_index_9  ...  \
# 0  2.358331e-05      0.000003      0.000003  7.440551e-07      0.000002  ...
# 1  1.999536e-04      0.000133      0.000224  3.195728e-04      0.000224  ...
# 2  2.784144e-04      0.000143      0.000039  6.137923e-05      0.000027  ...
# 3  4.118787e-07      0.000003      0.000001  2.556007e-06      0.000003  ...
# 4  4.494722e-05      0.000103      0.000017  1.099746e-05      0.000021  ...
#
#    prob_index_993  prob_index_994  prob_index_995  prob_index_996  \
# 0        0.000002        0.000001    7.887821e-07    7.520305e-07
# 1        0.000204        0.000215    4.614002e-05    4.976594e-05
# 2        0.000153        0.000150    1.367076e-04    9.844397e-05
# 3        0.000172        0.000213    2.282218e-04    7.214426e-05
# 4        0.000110        0.000173    1.211055e-04    5.923554e-05
#
#    prob_index_997  prob_index_998  prob_index_999  correctness  correctness  \
# 0        0.000003        0.000001    8.415565e-07            1            1
# 1        0.000065        0.000061    2.028638e-05            1            1
# 2        0.000128        0.000034    2.950774e-04            1            1
# 3        0.000430        0.000189    1.136141e-04            0            0
# 4        0.000130        0.000092    1.753411e-04            1            1
#
#    correct_cls_index
# 0                798
# 1                479
# 2                294
# 3                638
# 4                408
#
# [5 rows x 2003 columns]

# %% [markdown]
# ## Splitting training, validation and test sets

# %%
if dataset_split_type == 'split_by_random':  
    training_data_dim=traning_data.shape[1]-3
    
    traning_data["Set"] = np.random.choice(["train", "valid", "test"], p =[.8, .1, .1], size=(traning_data.shape[0],))

    train_indices = traning_data[traning_data.Set=="train"].index
    valid_indices = traning_data[traning_data.Set=="valid"].index
    test_indices = traning_data[traning_data.Set=="test"].index

    X_train = traning_data.iloc[:,:training_data_dim].values[train_indices]
    y_train = traning_data.iloc[:,training_data_dim:-1].values[train_indices]#.reshape(-1, 3)

    X_valid = traning_data.iloc[:,:training_data_dim].values[valid_indices]
    y_valid = traning_data.iloc[:,training_data_dim:-1].values[valid_indices]#.reshape(-1, 3)

    X_test = traning_data.iloc[:,:training_data_dim].values[test_indices]
    y_test = traning_data.iloc[:,training_data_dim:-1].values[test_indices]#.reshape(-1, 3)
    print(X_valid.shape,y_valid.shape)

elif dataset_split_type == 'split_by_json':
    training_data_dim = traning_data.shape[1]-3

    # Add index to the last column
    traning_data = pd.concat([traning_data,data_shallow.iloc[:,0]],axis=1)

    with open(json_for_estimator) as f:
        estimator_split = json.load(f)

    X_train = traning_data[traning_data['index_in_dataset'].isin(estimator_split['index_train'])].iloc[:,:training_data_dim].values
    y_train = traning_data[traning_data['index_in_dataset'].isin(estimator_split['index_train'])].iloc[:,training_data_dim:-1].values

    X_valid = traning_data[traning_data['index_in_dataset'].isin(estimator_split['index_val'])].iloc[:,:training_data_dim].values
    y_valid = traning_data[traning_data['index_in_dataset'].isin(estimator_split['index_val'])].iloc[:,training_data_dim:-1].values 

    print(X_valid.shape, y_valid.shape) 
    
else:
    raise Exception('please provide dataset_split_type')
# Out:
# (19215, 2000) (19215, 3)

# %% [markdown]
# ## Define estimator model

# %%
clf = TabNetRegressor(optimizer_params=dict(lr=learning_rate),scheduler_fn=torch.optim.lr_scheduler.StepLR,scheduler_params={"gamma": 0.9, "step_size": 5})
# Out:
# c:\Users\yaoching\Desktop\ICCV_Smart_cascade_code\pytorch_tabnet\abstract_model.py:77: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")

# %% [markdown]
# ## Training TabNet

# %%
clf.fit(
    X_train=X_train, y_train=y_train,
    eval_set=[(X_train, y_train), (X_valid, y_valid)],
    eval_name=['train', 'valid'],
    # custom loss
    loss_fn=TSP_Loss(lambda_CDC_weight = lambda_CDC_weight, Loss_Base_weight = Loss_Base_weight),
    eval_metric=eval_metric,
    max_epochs=max_epochs,
    patience=15,
    batch_size=512, virtual_batch_size=128, #default:batch_size=1024, virtual_batch_size=128
    num_workers=0,
    drop_last=False
)
# Out:
# TSP_TabNet!
# epoch 0  | loss: 0.66471 | train_AIR: 0.68453 | valid_AIR: 0.65867 |  0:00:12s
# epoch 1  | loss: 0.24537 | train_AIR: 0.68146 | valid_AIR: 0.65689 |  0:00:22s
# epoch 2  | loss: 0.24084 | train_AIR: 0.68399 | valid_AIR: 0.65778 |  0:00:33s
# epoch 3  | loss: 0.23974 | train_AIR: 0.68544 | valid_AIR: 0.66178 |  0:00:44s
# epoch 4  | loss: 0.23837 | train_AIR: 0.68453 | valid_AIR: 0.65733 |  0:00:54s
# epoch 5  | loss: 0.23709 | train_AIR: 0.69305 | valid_AIR: 0.66311 |  0:01:04s
# epoch 6  | loss: 0.23605 | train_AIR: 0.69794 | valid_AIR: 0.67244 |  0:01:14s
# epoch 7  | loss: 0.23602 | train_AIR: 0.69685 | valid_AIR: 0.67378 |  0:01:25s
# epoch 8  | loss: 0.23535 | train_AIR: 0.69902 | valid_AIR: 0.67067 |  0:01:35s
# epoch 9  | loss: 0.23513 | train_AIR: 0.69938 | valid_AIR: 0.67156 |  0:01:46s
# epoch 10 | loss: 0.2348  | train_AIR: 0.69866 | valid_AIR: 0.672   |  0:01:57s
# epoch 11 | loss: 0.23454 | train_AIR: 0.70083 | valid_AIR: 0.67067 |  0:02:07s
# epoch 12 | loss: 0.23457 | train_AIR: 0.70264 | valid_AIR: 0.67067 |  0:02:18s
# epoch 13 | loss: 0.23431 | train_AIR: 0.69848 | valid_AIR: 0.668   |  0:02:28s
# epoch 14 | loss: 0.23437 | train_AIR: 0.70101 | valid_AIR: 0.66978 |  0:02:38s
# epoch 15 | loss: 0.23416 | train_AIR: 0.6992  | valid_AIR: 0.67111 |  0:02:49s
# epoch 16 | loss: 0.23409 | train_AIR: 0.70156 | valid_AIR: 0.67156 |  0:02:59s
# epoch 17 | loss: 0.23392 | train_AIR: 0.6992  | valid_AIR: 0.67067 |  0:03:10s
# epoch 18 | loss: 0.23385 | train_AIR: 0.70047 | valid_AIR: 0.672   |  0:03:20s
# epoch 19 | loss: 0.23377 | train_AIR: 0.69938 | valid_AIR: 0.67156 |  0:03:31s
# epoch 20 | loss: 0.23637 | train_AIR: 0.69359 | valid_AIR: 0.67689 |  0:03:42s
# epoch 21 | loss: 0.23463 | train_AIR: 0.69866 | valid_AIR: 0.67067 |  0:03:52s
# epoch 22 | loss: 0.2344  | train_AIR: 0.69812 | valid_AIR: 0.66978 |  0:04:03s
# epoch 23 | loss: 0.23434 | train_AIR: 0.70065 | valid_AIR: 0.67867 |  0:04:13s
# epoch 24 | loss: 0.23405 | train_AIR: 0.70065 | valid_AIR: 0.67422 |  0:04:23s
# epoch 25 | loss: 0.23373 | train_AIR: 0.69739 | valid_AIR: 0.67556 |  0:04:34s
# epoch 26 | loss: 0.23368 | train_AIR: 0.69721 | valid_AIR: 0.67156 |  0:04:44s
# epoch 27 | loss: 0.23355 | train_AIR: 0.70047 | valid_AIR: 0.67467 |  0:04:55s
# epoch 28 | loss: 0.23353 | train_AIR: 0.70011 | valid_AIR: 0.67378 |  0:05:06s
# epoch 29 | loss: 0.23326 | train_AIR: 0.70065 | valid_AIR: 0.67111 |  0:05:17s
# epoch 30 | loss: 0.23298 | train_AIR: 0.69993 | valid_AIR: 0.67022 |  0:05:27s
# epoch 31 | loss: 0.23293 | train_AIR: 0.69957 | valid_AIR: 0.66978 |  0:05:38s
# epoch 32 | loss: 0.23303 | train_AIR: 0.69975 | valid_AIR: 0.66889 |  0:05:50s
# epoch 33 | loss: 0.23293 | train_AIR: 0.69902 | valid_AIR: 0.668   |  0:06:01s
# epoch 34 | loss: 0.23287 | train_AIR: 0.69848 | valid_AIR: 0.668   |  0:06:11s
# epoch 35 | loss: 0.2325  | train_AIR: 0.69884 | valid_AIR: 0.67244 |  0:06:22s
# epoch 36 | loss: 0.23283 | train_AIR: 0.69993 | valid_AIR: 0.66978 |  0:06:33s
# epoch 37 | loss: 0.23264 | train_AIR: 0.69794 | valid_AIR: 0.66978 |  0:06:43s
# epoch 38 | loss: 0.23256 | train_AIR: 0.7012  | valid_AIR: 0.67244 |  0:06:54s
#
# Early stopping occurred at epoch 38 with best_epoch = 23 and best_valid_AIR = 0.67867
# c:\Users\yaoching\Desktop\ICCV_Smart_cascade_code\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)

# %% [markdown]
# ## Saving weight of estimator

# %%
#save tabnet model
saved_filepath = clf.save_model(saving_weight_name)
# Out:
# Successfully saved model at c:\Users\yaoching\Desktop\ICCV_Smart_cascade_code\estimator_weights\weights_ImageNet_tf_efficientnet_b0_ImageNet_resnet101_ImageNet\TabNet_L-Overall_AIR_Seed_1.zip

# %% [markdown]
# ## Toy test

# %%
print(clf.predict(np.array([1.0,0.,0.,0.,0.,0.]+[0.0]*994).reshape(-1,1000)))
print(clf.predict(np.array([0.9,0.1,0.,0.,0.,0.]+[0.0]*994).reshape(-1,1000)))
print(clf.predict(np.array([0.8,0.2,0.,0.,0.,0.]+[0.0]*994).reshape(-1,1000)))
print(clf.predict(np.array([0.7,0.3,0.,0.,0.,0.]+[0.0]*994).reshape(-1,1000)))
# Out:
# [[1.0453709]]
# [[0.87544674]]
# [[0.7082589]]
# [[0.6741762]]
